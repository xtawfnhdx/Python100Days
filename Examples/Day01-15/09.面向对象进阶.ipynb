# %% [markdown]
# ## 面向对象进阶

# %% [markdown]
# ### @property装饰器
#
# 使用@property 和 @XX.setter 包装getter和setter方法

# %%
class Person(object):
    def __init__(self,name,age):
        self._name=name
        self._age=age
        
    @property
    def name(self):
        print(self._name)
        
    @property
    def age(self):
        print(self._age)
        
    @age.setter
    def age(self,age):
        self._age=age
        
    @name.setter
    def name(self,name):
        self._name=name
    
    def pr(self):
        if self._age <= 16:
            print('%s正在玩飞行棋.' % self._name)
        else:
            print('%s正在玩斗地主.' % self._name)
            
if __name__ == "__main__":
    person=Person("zhangsan",15)
    person.age=22
    person.xxs=33
    person.pr()
    print(person.xxs)
# Out:
# zhangsan正在玩斗地主.
# 33

# %% [markdown]
# #### \_\_slots\_\_ 限定

# %%
class Person(object):
    #限定对象只能绑定属性_name和_age
    __slots__=("_name","_age")
    
    def __init__(self,name,age):
        self._name=name
        self._age=age
        
    @property
    def name(self):
        print(self._name)
        
    @property
    def age(self):
        print(self._age)
        
    @age.setter
    def age(self,age):
        self._age=age
        
    @name.setter
    def name(self,name):
        self._name=name
    
    def pr(self):
        if self._age <= 16:
            print('%s正在玩飞行棋.' % self._name)
        else:
            print('%s正在玩斗地主.' % self._name)
            
if __name__ == "__main__":
    person=Person("zhangsan",15)
    person.age=22
    person.xxs=33
    person.pr()
    print(person.xxs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1c74f7de78ad> in <module>
#      32     person=Person("zhangsan",15)
#      33     person.age=22
# ---> 34     person.xxs=33
#      35     person.pr()
#      36     print(person.xxs)
#
# AttributeError: 'Person' object has no attribute 'xxs'

# %% [markdown]
# #### 静态方法使用@staticmethod标记

# %%
class Person(object):
    
    @staticmethod
    def Test():
        print("this is static method")
        
if __name__ == "__main__":
    Person.Test()
# Out:
# this is static method

# %% [markdown]
# #### 类方法使用@classmethod标记

# %%
from time import time,localtime,sleep

class Clock(object):
    
    def __init__(self,hour=0,minute=0,second=0):
        self._hour=hour
        self._minute=minute
        self._second=second
    
    @classmethod
    def now(cls):
        ctime=localtime(time())
        return cls(ctime.tm_hour,ctime.tm_min,ctime.tm_sec)
    
    def run(self):
        self._second += 1
        if self._second == 60:
            self._second = 0
            self._minute += 1
            if self._minute == 60:
                self._minute = 0
                self._hour += 1
                if self._hour == 24:
                    self._hour = 0
    
    def show(self):
        return '%20d:%20d:%20d' % (self._hour,self._minute,self._second)
    
def main():
        clock=Clock.now()
        i=0
        while i<10:
            print(clock.show())
            sleep(1)
            clock.run()
            i+=1

if __name__ == '__main__':
    main()
# Out:
#                   14:                   7:                   0
#                   14:                   7:                   1
#                   14:                   7:                   2
#                   14:                   7:                   3
#                   14:                   7:                   4
#                   14:                   7:                   5
#                   14:                   7:                   6
#                   14:                   7:                   7
#                   14:                   7:                   8
#                   14:                   7:                   9

# %% [markdown]
# ### 继承

# %%
class Person(object):
    def __init__(self,name,age):
        self._name=name
        self._age=age
        
    @property
    def name(self):
        return self._name
    
    @property
    def age(self):
        return self._age
    
    @age.setter
    def age(self,age):
        self._age=age
    
    def play(self):
        print('%s正在愉快的玩耍' % (self._name))
        
    def watch_av(self):
        if self._age >= 18:
            print('%s正在观看爱情动作片.' % self._name)
        else:
            print('%s只能观看《熊出没》.' % self._name)
            
class Student(Person):
    def __init__(self,name,age,grade):
        super().__init__(name,age)
        self._grade=grade
        
    @property
    def grade(self):
        return self._grade
    
    @grade.setter
    def grade(self,grade):
        self._grade=grade
        
    def study(self,course):
        print('%s的%s正在学习%s.' % (self._grade,self._name,course))
        
class Teacher(Person):
    def __init__(self,name,age,title):
        super().__init__(name,age)
        self._title=title
        
    @property
    def title(self):
        return self._title

    @title.setter
    def title(self, title):
        self._title = title

    def teach(self, course):
        print('%s%s正在讲%s.' % (self._name, self._title, course))
        
def main():
    stu = Student("王大锤",15,"初三")
    stu.study('数学')
    stu.watch_av()
    t = Teacher('骆昊', 38, '砖家')
    t.teach('Python程序设计')
    t.watch_av()
    
if __name__=="__main__":
    main()
# Out:
# 初三的王大锤正在学习数学.
# 王大锤只能观看《熊出没》.
# 骆昊砖家正在讲Python程序设计.
# 骆昊正在观看爱情动作片.

# %%
class Person(object):
    def __init__(self,name,age):
        self._name=name
        self._age=age
        
    @property
    def name(self):
        return self._name
    
    @property
    def age(self):
        return self._age
    
    @age.setter
    def age(self,age):
        self._age=age
    
    def play1(self):
        print('%s正在愉快的玩耍' % (self._name))
        
    def watch_av(self):
        if self._age >= 18:
            print('%s正在观看爱情动作片.' % self._name)
        else:
            print('%s只能观看《熊出没》.' % self._name)
            
class Man(object):
    def __init__(self,sex):
        self._sex=sex
        
    @property
    def sex(self):
        return self._sex
    
    @property
    def sex(self):
        return self._sex
    
    @sex.setter
    def sex(self,sex):
        self._sex=sex
    
    def play2(self):
        print('%s性别：%s' % (self._name,self._sex))
        
class Zhangsan(Person,Man):
    def __init__(self,name,age,sex):
        Person.__init__(self,name,age)
        Man.__init__(self,sex)
        
def main():
    stu = Zhangsan("王大锤",15,"男")
    stu.play1()
    stu.play2()
    
if __name__=="__main__":
    main()
# Out:
# 王大锤正在愉快的玩耍
# 王大锤性别：男

# %% [markdown]
# #### 深度遍历和广度遍历
# super().\_\_init__ 是广度遍历，父类的父类，只执行一遍
#
# 父类名称.\_\_init__ 是深度遍历，有时候会导致父类函数执行多次

# %%
class A(object):
    def __init__(self):
        print("A")
        
class B(A):
    def __init__(self):
        print("B")
        
class C(A):
    def __init__(self):
        print("C")
        
class D(B,C):
    def __init__(self):
        print("D")
        
        
D()
# Out:
# D

# %%
class A(object):
    def __init__(self):
        print("A")
        
class B(A):
    def __init__(self):
        print("B")
        
class C(A):
    def __init__(self):
        print("C")
        
class D(B,C):
    pass  
        
D()
# Out:
# B

# %% [markdown]
# #### 函数方法重写

# %%
#abc 是表示python的一个抽象基类
from abc import ABCMeta,abstractmethod

class Pet(object,metaclass=ABCMeta):
    
    def __init__(self,nickname):
        self._nickname=nickname
        
    @abstractmethod
    def make_voice(self):
        pass
    
class Dog(Pet):
    def make_voice(self):
        print('%s: 汪汪汪...' % self._nickname)
        
class Cat(Pet):
    def make_voice(self):
        print('%s: 喵~~喵~~...' % self._nickname)
        
def main():
    pets=[Dog("旺财"),Cat("小花"),Dog("大黄")]
    for pet in pets:
        pet.make_voice()
        
if __name__ == "__main__":
    main()
# Out:
# 旺财: 汪汪汪...
# 小花: 喵~~喵~~...
# 大黄: 汪汪汪...

# %%
from abc import ABCMeta, abstractmethod
from random import randint, randrange


class Fighter(object, metaclass=ABCMeta):
    """战斗者"""

    # 通过__slots__魔法限定对象可以绑定的成员变量
    __slots__ = ('_name', '_hp')

    def __init__(self, name, hp):
        """初始化方法

        :param name: 名字
        :param hp: 生命值
        """
        self._name = name
        self._hp = hp

    @property
    def name(self):
        return self._name

    @property
    def hp(self):
        return self._hp

    @hp.setter
    def hp(self, hp):
        self._hp = hp if hp >= 0 else 0

    @property
    def alive(self):
        return self._hp > 0

    @abstractmethod
    def attack(self, other):
        """攻击

        :param other: 被攻击的对象
        """
        pass


class Ultraman(Fighter):
    """奥特曼"""

    __slots__ = ('_name', '_hp', '_mp')

    def __init__(self, name, hp, mp):
        """初始化方法

        :param name: 名字
        :param hp: 生命值
        :param mp: 魔法值
        """
        super().__init__(name, hp)
        self._mp = mp

    def attack(self, other):
        other.hp -= randint(15, 25)

    def huge_attack(self, other):
        """究极必杀技(打掉对方至少50点或四分之三的血)

        :param other: 被攻击的对象

        :return: 使用成功返回True否则返回False
        """
        if self._mp >= 50:
            self._mp -= 50
            injury = other.hp * 3 // 4
            injury = injury if injury >= 50 else 50
            other.hp -= injury
            return True
        else:
            self.attack(other)
            return False

    def magic_attack(self, others):
        """魔法攻击

        :param others: 被攻击的群体

        :return: 使用魔法成功返回True否则返回False
        """
        if self._mp >= 20:
            self._mp -= 20
            for temp in others:
                if temp.alive:
                    temp.hp -= randint(10, 15)
            return True
        else:
            return False

    def resume(self):
        """恢复魔法值"""
        incr_point = randint(1, 10)
        self._mp += incr_point
        return incr_point

    def __str__(self):
        return '~~~%s奥特曼~~~\n' % self._name + \
            '生命值: %d\n' % self._hp + \
            '魔法值: %d\n' % self._mp


class Monster(Fighter):
    """小怪兽"""

    __slots__ = ('_name', '_hp')

    def attack(self, other):
        other.hp -= randint(10, 20)

    def __str__(self):
        return '~~~%s小怪兽~~~\n' % self._name + \
            '生命值: %d\n' % self._hp


def is_any_alive(monsters):
    """判断有没有小怪兽是活着的"""
    for monster in monsters:
        if monster.alive > 0:
            return True
    return False


def select_alive_one(monsters):
    """选中一只活着的小怪兽"""
    monsters_len = len(monsters)
    while True:
        index = randrange(monsters_len)
        monster = monsters[index]
        if monster.alive > 0:
            return monster


def display_info(ultraman, monsters):
    """显示奥特曼和小怪兽的信息"""
    print(ultraman)
    for monster in monsters:
        print(monster, end='')


def main():
    u = Ultraman('骆昊', 1000, 120)
    m1 = Monster('狄仁杰', 250)
    m2 = Monster('白元芳', 500)
    m3 = Monster('王大锤', 750)
    ms = [m1, m2, m3]
    fight_round = 1
    while u.alive and is_any_alive(ms):
        print('========第%02d回合========' % fight_round)
        m = select_alive_one(ms)  # 选中一只小怪兽
        skill = randint(1, 10)   # 通过随机数选择使用哪种技能
        if skill <= 6:  # 60%的概率使用普通攻击
            print('%s使用普通攻击打了%s.' % (u.name, m.name))
            u.attack(m)
            print('%s的魔法值恢复了%d点.' % (u.name, u.resume()))
        elif skill <= 9:  # 30%的概率使用魔法攻击(可能因魔法值不足而失败)
            if u.magic_attack(ms):
                print('%s使用了魔法攻击.' % u.name)
            else:
                print('%s使用魔法失败.' % u.name)
        else:  # 10%的概率使用究极必杀技(如果魔法值不足则使用普通攻击)
            if u.huge_attack(m):
                print('%s使用究极必杀技虐了%s.' % (u.name, m.name))
            else:
                print('%s使用普通攻击打了%s.' % (u.name, m.name))
                print('%s的魔法值恢复了%d点.' % (u.name, u.resume()))
        if m.alive > 0:  # 如果选中的小怪兽没有死就回击奥特曼
            print('%s回击了%s.' % (m.name, u.name))
            m.attack(u)
        display_info(u, ms)  # 每个回合结束后显示奥特曼和小怪兽的信息
        fight_round += 1
    print('\n========战斗结束!========\n')
    if u.alive > 0:
        print('%s奥特曼胜利!' % u.name)
    else:
        print('小怪兽胜利!')


if __name__ == '__main__':
    main()
# Out:
# ========第01回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了5点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 988
# 魔法值: 125
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 250
# ~~~白元芳小怪兽~~~
# 生命值: 500
# ~~~王大锤小怪兽~~~
# 生命值: 733
# ========第02回合========
# 骆昊使用究极必杀技虐了狄仁杰.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 969
# 魔法值: 75
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 63
# ~~~白元芳小怪兽~~~
# 生命值: 500
# ~~~王大锤小怪兽~~~
# 生命值: 733
# ========第03回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了8点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 958
# 魔法值: 83
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 63
# ~~~白元芳小怪兽~~~
# 生命值: 500
# ~~~王大锤小怪兽~~~
# 生命值: 717
# ========第04回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 943
# 魔法值: 63
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 51
# ~~~白元芳小怪兽~~~
# 生命值: 490
# ~~~王大锤小怪兽~~~
# 生命值: 706
# ========第05回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了2点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 931
# 魔法值: 65
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 51
# ~~~白元芳小怪兽~~~
# 生命值: 490
# ~~~王大锤小怪兽~~~
# 生命值: 688
# ========第06回合========
# 骆昊使用究极必杀技虐了狄仁杰.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 920
# 魔法值: 15
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 1
# ~~~白元芳小怪兽~~~
# 生命值: 490
# ~~~王大锤小怪兽~~~
# 生命值: 688
# ========第07回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了5点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 908
# 魔法值: 20
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 1
# ~~~白元芳小怪兽~~~
# 生命值: 465
# ~~~王大锤小怪兽~~~
# 生命值: 688
# ========第08回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了5点.
# ~~~骆昊奥特曼~~~
# 生命值: 908
# 魔法值: 25
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 465
# ~~~王大锤小怪兽~~~
# 生命值: 688
# ========第09回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了9点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 894
# 魔法值: 34
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 465
# ~~~王大锤小怪兽~~~
# 生命值: 666
# ========第10回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 878
# 魔法值: 14
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 451
# ~~~王大锤小怪兽~~~
# 生命值: 656
# ========第11回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了6点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 859
# 魔法值: 20
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 427
# ~~~王大锤小怪兽~~~
# 生命值: 656
# ========第12回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了5点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 839
# 魔法值: 25
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 411
# ~~~王大锤小怪兽~~~
# 生命值: 656
# ========第13回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了8点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 820
# 魔法值: 33
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 411
# ~~~王大锤小怪兽~~~
# 生命值: 640
# ========第14回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了5点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 807
# 魔法值: 38
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 390
# ~~~王大锤小怪兽~~~
# 生命值: 640
# ========第15回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了4点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 793
# 魔法值: 42
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 373
# ~~~王大锤小怪兽~~~
# 生命值: 640
# ========第16回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了9点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 783
# 魔法值: 51
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 373
# ~~~王大锤小怪兽~~~
# 生命值: 623
# ========第17回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了8点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 772
# 魔法值: 59
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 373
# ~~~王大锤小怪兽~~~
# 生命值: 600
# ========第18回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了7点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 754
# 魔法值: 66
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 355
# ~~~王大锤小怪兽~~~
# 生命值: 600
# ========第19回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 744
# 魔法值: 46
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 344
# ~~~王大锤小怪兽~~~
# 生命值: 585
# ========第20回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了6点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 724
# 魔法值: 52
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 322
# ~~~王大锤小怪兽~~~
# 生命值: 585
# ========第21回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了9点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 705
# 魔法值: 61
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 322
# ~~~王大锤小怪兽~~~
# 生命值: 566
# ========第22回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 687
# 魔法值: 41
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 311
# ~~~王大锤小怪兽~~~
# 生命值: 554
# ========第23回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了9点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 669
# 魔法值: 50
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 292
# ~~~王大锤小怪兽~~~
# 生命值: 554
# ========第24回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了9点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 658
# 魔法值: 59
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 292
# ~~~王大锤小怪兽~~~
# 生命值: 536
# ========第25回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了2点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 642
# 魔法值: 61
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 267
# ~~~王大锤小怪兽~~~
# 生命值: 536
# ========第26回合========
# 骆昊使用究极必杀技虐了白元芳.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 627
# 魔法值: 11
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 67
# ~~~王大锤小怪兽~~~
# 生命值: 536
# ========第27回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 617
# 魔法值: 11
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 67
# ~~~王大锤小怪兽~~~
# 生命值: 536
# ========第28回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了1点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 598
# 魔法值: 12
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 45
# ~~~王大锤小怪兽~~~
# 生命值: 536
# ========第29回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了6点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 584
# 魔法值: 18
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 27
# ~~~王大锤小怪兽~~~
# 生命值: 536
# ========第30回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 569
# 魔法值: 18
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 27
# ~~~王大锤小怪兽~~~
# 生命值: 536
# ========第31回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了9点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 553
# 魔法值: 27
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 27
# ~~~王大锤小怪兽~~~
# 生命值: 520
# ========第32回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了3点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 541
# 魔法值: 30
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 27
# ~~~王大锤小怪兽~~~
# 生命值: 497
# ========第33回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了5点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 521
# 魔法值: 35
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 27
# ~~~王大锤小怪兽~~~
# 生命值: 473
# ========第34回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 501
# 魔法值: 15
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 15
# ~~~王大锤小怪兽~~~
# 生命值: 458
# ========第35回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了6点.
# ~~~骆昊奥特曼~~~
# 生命值: 501
# 魔法值: 21
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 458
# ========第36回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 485
# 魔法值: 22
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 436
# ========第37回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 466
# 魔法值: 23
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 413
# ========第38回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 451
# 魔法值: 24
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 392
# ========第39回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了7点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 431
# 魔法值: 31
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 374
# ========第40回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 418
# 魔法值: 32
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 353
# ========第41回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 404
# 魔法值: 33
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 329
# ========第42回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了6点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 393
# 魔法值: 39
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 306
# ========第43回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了10点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 381
# 魔法值: 49
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 285
# ========第44回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了7点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 361
# 魔法值: 56
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 267
# ========第45回合========
# 骆昊使用究极必杀技虐了王大锤.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 347
# 魔法值: 6
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 67
# ========第46回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 333
# 魔法值: 6
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 67
# ========第47回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 314
# 魔法值: 6
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 67
# ========第48回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 295
# 魔法值: 6
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 67
# ========第49回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 280
# 魔法值: 7
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 44
# ========第50回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 264
# 魔法值: 7
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 44
# ========第51回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了5点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 246
# 魔法值: 12
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 21
# ========第52回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 230
# 魔法值: 13
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 4
# ========第53回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# ~~~骆昊奥特曼~~~
# 生命值: 230
# 魔法值: 14
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 0
#
# ========战斗结束!========
#
# 骆昊奥特曼胜利!
